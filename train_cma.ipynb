# %%
# ============================================================
# Cell 0: GPU 可用性检查
# ============================================================
# 功能：使用 nvidia-smi 命令检查当前环境的 GPU 信息
# 输出：显示 GPU 型号、驱动版本、CUDA 版本、显存使用情况等
# 用途：确认 Colab 是否分配了 GPU，以及 GPU 的当前状态
# ============================================================
# !nvidia-smi
# Out:
# Wed Mar  4 09:24:07 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   36C    P0             56W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# ============================================================
# Cell 1: 从 GitHub 克隆项目仓库
# ============================================================
# 功能：使用 GitHub Personal Access Token (PAT) 克隆私有仓库
# 步骤：
#   1. 提示用户输入 GitHub Token (使用 getpass 隐藏输入)
#   2. 使用 Token 克隆仓库到 /content/ProjectExperiment
#   3. 检查克隆是否成功
#   4. 切换到项目目录并列出文件
#
# 注意：Token 需要具有 repo 权限才能访问私有仓库
# ============================================================
from getpass import getpass
import os

# 提示输入 GitHub Token (用于访问私有仓库)
token = getpass('Enter your GitHub Personal Access Token: ')

# 使用 Token 进行克隆
user_repo = 'szaaaaaa/ProjectExperiment'
# !git clone https://{token}@github.com/{user_repo}.git

# 检查克隆是否成功并切换目录
if os.path.exists('ProjectExperiment'):
    # %cd ProjectExperiment
    # !ls
else:
    print("Clone failed. Please check your token or repository URL.")
# Out:
# Enter your GitHub Personal Access Token: ··········
# Cloning into 'ProjectExperiment'...
# remote: Enumerating objects: 632, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 632 (delta 82), reused 130 (delta 55), pack-reused 457 (from 1)
# Receiving objects: 100% (632/632), 2.23 MiB | 50.75 MiB/s, done.
# Resolving deltas: 100% (305/305), done.
# /content/ProjectExperiment
# CLAUDE.md  docs     README.md	  runs	   src	  train.ipynb
# configs    encoder  README_zh.md  scripts  tests

# %% [markdown]
# ### 🛠️ 如何生成 GitHub Personal Access Token (PAT)
#
# 为了访问私有仓库或通过脚本操作 GitHub，您需要一个 Token。请按照以下步骤生成：
#
# 1.  **登录 GitHub**: 访问 [github.com](https://github.com) 并登录您的账号。
# 2.  **进入设置**: 点击页面右上角的头像，选择 **Settings** (设置)。
# 3.  **开发者设置**: 在左侧边栏的最底部，点击 **Developer settings**。
# 4.  **选择 Token 类型**: 在左侧菜单中点击 **Personal access tokens** -> **Tokens (classic)** (推荐使用 Classic 模式，兼容性更好)。
# 5.  **生成新 Token**: 点击右侧的 **Generate new token** 按钮，选择 **Generate new token (classic)**。
# 6.  **配置 Token**:
#     *   **Note**: 给 Token 起个名字，例如 `Colab Access`。
#     *   **Expiration**: 设置过期时间（例如 30 days，或者 No expiration）。
#     *   **Scopes (权限)**: **务必勾选 `repo`** 复选框（这会授予对私有仓库的完全读写权限）。
# 7.  **生成并复制**: 点击页面底部的 **Generate token** 绿涩按钮。
# 8.  **保存 Token**: 页面会显示一串以 `ghp_` 开头的字符，**立即复制它**（刷新页面后它将不再显示）。
#
# 👉 **接下来**: 回到 Colab，运行上面的代码单元格，当提示输入 Token 时，粘贴您刚才复制的字符串并回车。

# %%
# ============================================================
# Cell 3: 挂载 Google Drive
# ============================================================
# 功能：将 Google Drive 挂载到 Colab 环境的 /content/drive 目录
# 用途：
#   - 访问存储在 Google Drive 中的数据集
#   - 保存训练结果和模型检查点到云端
#   - 实现数据和结果的持久化存储
#
# 首次运行会弹出授权窗口，需要登录 Google 账号授权
# ============================================================
from google.colab import drive

# 挂载 Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# Cell 3.5: 一次性目录整理（只需运行一次）
# ============================================================
# 将视频目录从 AmuCS_experiment 移到 AmuCS 原始数据集中
# 287GB，在 Colab 挂载的 Drive 上是元数据操作（秒级完成）
#
# 运行前确认：AmuCS_experiment 目录已存在
# 运行后结果：gameplay_videos_nospeech 和 data 并列在 researchdata/ 下
# ============================================================
import os, shutil

src = "/content/drive/MyDrive/AmuCS_experiment/AmuCSVideo_unzipped/researchdata/gameplay_videos_nospeech"
dst = "/content/drive/MyDrive/AmuCS/Affective Multimodal Counter-Strike video game dataset (AMuCS) - Public/researchdata/gameplay_videos_nospeech"

if os.path.exists(src) and not os.path.exists(dst):
    print(f"Moving {src} -> {dst}")
    shutil.move(src, dst)
    print("Done!")
elif os.path.exists(dst):
    print("Already moved. Skipping.")
else:
    print(f"Source not found: {src}")

# %%
# ============================================================
# Cell 4: 读取并显示基础配置文件
# ============================================================
# 功能：读取项目的基础配置文件 base.yaml 并打印其内容
# 配置文件包含：
#   - data: 数据集路径、模态列表、窗口长度等
#   - model: 模型架构参数（编码器、融合、预测头）
#   - train: 训练超参数（学习率、批大小、早停策略）
#   - eval: 评估指标
#
# 用途：了解项目的默认配置，实验配置会继承并覆盖这些默认值
# ============================================================
import yaml

config_path = 'configs/base.yaml'

# 读取配置文件内容
with open(config_path, 'r') as file:
    config_content = file.read()

print(config_content)
# Out:
# ﻿# ─────────────────────────────────────────────────────────
# # Base configuration — global defaults
# # 基础配置 — 全局默认值
# #
# # Experiments inherit from this via _base_: ../base.yaml
# # ─────────────────────────────────────────────────────────
#
# data:
#   name: amucs
#   modalities: [video, km]
#   data_root: data/features/amucs
#   labels_path: G:/我的云端硬盘/AmuCS_experiment/labels/labels_arousal.json
#   split_path: data/splits/multimodal_split.json
#   normalize: true
#   win_lens:
#     video: 24
#     km: 300
#
# model:
#   d_model: 512
#   encoders:
#     video:
#       name: resnet2d
#       feature_dim: 2048
#       dropout: 0.1
#       temporal_pool: mean
#     km:
#       name: stat
#       feature_dim: 25
#   fusion:
#     name: lft
#     nhead: 8
#     num_layers: 4
#     dim_feedforward: 1024
#     dropout: 0.1
#     max_seq_len: 1000
#     pos_encoding_type: sinusoidal
#     pooling: mean
#   head:
#     name: regression
#     hidden_dim: 128
#     out_dim: 1
# ...

# %%
# ============================================================
# Cell 5: 视频特征提取脚本帮助信息和目录检查
# ============================================================
# 检查 extract_video_features.py 脚本用法和视频目录内容
# ============================================================

# !python scripts/extract_video_features.py --help

# 注意：视频目录需要先在 Colab 上执行 Cell 3.5 的移动命令
video_path = '/content/drive/MyDrive/AmuCS/Affective Multimodal Counter-Strike video game dataset (AMuCS) - Public/researchdata/gameplay_videos_nospeech'
# !ls "{video_path}" | head -n 5
# Out:
# usage: extract_video_features.py [-h] --video_dir VIDEO_DIR
#                                  [--output_dir OUTPUT_DIR]
#                                  [--target_fps TARGET_FPS]
#                                  [--frame_size FRAME_SIZE]
#                                  [--batch_size BATCH_SIZE] [--device DEVICE]
#                                  [--amp] [--no_pretrained] [--no_freeze]
#                                  [--session_mode {auto,flat,subdirs}]
#                                  [--done_dir DONE_DIR] [--overwrite]
#                                  [--name_mode {auto,raw,session_prefix,amucs}]
#
# Extract gameplay features using ResNet-50
#
# options:
#   -h, --help            show this help message and exit
#   --video_dir VIDEO_DIR
#                         Directory with video files
#   --output_dir OUTPUT_DIR
#                         Output directory for .pt files
#   --target_fps TARGET_FPS
#                         Target sampling FPS
# ...

# %%
# ============================================================
# Cell 6: 同步远程仓库最新代码
# ============================================================
# 功能：
#   1. 确保当前在项目根目录
#   2. 从 GitHub 拉取最新代码
#
# 用途：获取团队其他成员的最新代码更新或修复
# 注意：如果有本地未提交的修改，可能会产生冲突
# ============================================================

# 确保位于项目目录
# %cd /content/ProjectExperiment

# 拉取远程仓库的最新更改
# !git pull
# Out:
# /content/ProjectExperiment
# Already up to date.

# %%
# ============================================================
# Cell 7: 游戏视频特征提取（使用 ResNet-50）
# ============================================================
# 使用预训练 ResNet-50 从游戏视频中提取帧级深度特征
# 输出：每个视频生成 .pt 文件（如 S001_P1.pt）
# ============================================================
# %%bash
python scripts/extract_video_features.py \
  --video_dir "/content/drive/MyDrive/AmuCS/Affective Multimodal Counter-Strike video game dataset (AMuCS) - Public/researchdata/gameplay_videos_nospeech" \
  --output_dir "/content/drive/MyDrive/AmuCS_experiment/features/video" \
  --session_mode subdirs \
  --device cuda \
  --amp
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# Found 58 session(s), total videos: 188
# Skip session S001: marked done
# Skip session S002: marked done
# Skip session S003: marked done
# Skip session S004: marked done
# Skip session S005: marked done
# Skip session S006: marked done
# Skip session S007: marked done
# Skip session S008: marked done
# Skip session S009: marked done
# Skip session S011: marked done
# Skip session S012: marked done
# Skip session S013: marked done
# Skip session S014: marked done
# Skip session S015: marked done
# Skip session S016: marked done
# Skip session S017: marked done
# Skip session S018: marked done
# Skip session S019: marked done
# Skip session S020: marked done
# Skip session S021: marked done
# Skip session S022: marked done
# Skip session S023: marked done
# Skip session S024: marked done
# Skip session S025: marked done
# ...

# %%
# ============================================================
# Cell 8: 配置键盘鼠标特征提取的路径
# ============================================================
ROOT_DIR = "/content/drive/MyDrive/AmuCS/Affective Multimodal Counter-Strike video game dataset (AMuCS) - Public/researchdata/data"
OUT_DIR  = "/content/drive/MyDrive/AmuCS_experiment/features/km"

# %%
# ============================================================
# Cell 9: 键盘鼠标特征提取
# ============================================================
# 从原始 CSV 中提取键盘和鼠标交互行为的统计特征
# ============================================================
import os
os.makedirs(OUT_DIR, exist_ok=True)

print(f"Source: {ROOT_DIR}")
print(f"Target: {OUT_DIR}")

# !python scripts/extract_km_features.py \
  --root_dir "{ROOT_DIR}" \
  --output_dir "{OUT_DIR}" \
  --encoder stat
# Out:
# Source: /content/drive/MyDrive/AmuCS/Affective Multimodal Counter-Strike video game dataset (AMuCS) - Public/researchdata/data
# Target: /content/drive/MyDrive/AmuCS_experiment/features/km
# Processing S001/P3...
#   Skipped (already exists): S001_P3.pt
# Processing S001/P4...
#   Skipped (already exists): S001_P4.pt
# Processing S002/P2...
#   Skipped (already exists): S002_P2.pt
# Processing S003/P2...
#   Skipped (already exists): S003_P2.pt
# Processing S003/P3...
#   Skipped (already exists): S003_P3.pt
# Processing S003/P4...
#   Skipped (already exists): S003_P4.pt
# Processing S004/P3...
#   Skipped (already exists): S004_P3.pt
# Processing S004/P4...
#   Skipped (no data files)
# Processing S005/P1...
#   Skipped (already exists): S005_P1.pt
# Processing S005/P2...
#   Skipped (already exists): S005_P2.pt
# Processing S006/P1...
#   Skipped (already exists): S006_P1.pt
# Processing S006/P2...
#   Skipped (already exists): S006_P2.pt
# Processing S006/P3...
# ...

# %%
# ============================================================
# Cell 9.5: 游戏遥测（Telemetry）特征提取
# ============================================================
# 从 gameFlt.csv + gameInt.csv 提取对齐的遥测特征
# 输出目录：/content/drive/MyDrive/AmuCS_experiment/features/telem
# ============================================================
import os

OUT_DIR_TELEM = "/content/drive/MyDrive/AmuCS_experiment/features/telem"
os.makedirs(OUT_DIR_TELEM, exist_ok=True)

print(f"Source: {ROOT_DIR}")
print(f"Target: {OUT_DIR_TELEM}")

# !python scripts/extract_game_telem_features.py \
  --root_dir "{ROOT_DIR}" \
  --output_dir "{OUT_DIR_TELEM}" \
  --km_dir "/content/drive/MyDrive/AmuCS_experiment/features/km" \
  --dt 0.2
# Out:
# Source: /content/drive/MyDrive/AmuCS/Affective Multimodal Counter-Strike video game dataset (AMuCS) - Public/researchdata/data
# Target: /content/drive/MyDrive/AmuCS_experiment/features/telem
# Common stems (km ∩ telem ∩ arousal): 227
#
# Done: saved=0, skipped=227, errors=0
# Fixed feature_dim: 109

# %%
# ============================================================
# Cell 10: 定义项目全局路径变量
# ============================================================
# 集中定义所有后续步骤需要的路径变量，避免硬编码
# ============================================================

PROJECT_ROOT = "/content/ProjectExperiment"
AMUCS_RAW = "/content/drive/MyDrive/AmuCS/Affective Multimodal Counter-Strike video game dataset (AMuCS) - Public/researchdata"
AMUCS_EXP = "/content/drive/MyDrive/AmuCS_experiment"

FEATURE_ROOT = f"{AMUCS_EXP}/features"          # video/, km/, telem/
ALIGNED_ROOT = FEATURE_ROOT                       # use raw unaligned features for CMA
LABELS_DIR   = f"{AMUCS_EXP}/labels"
SPLITS_DIR   = f"{AMUCS_EXP}/splits"
RUNS_DIR     = f"{AMUCS_EXP}/runs"

# %%
# ============================================================
# Cell 11: ??????????video + km + telem?
# ============================================================
# CMA ????????????????? sync_data.py
# ============================================================
# %%bash
set -euo pipefail
cd /content/ProjectExperiment
echo "Skip sync_data.py: CMA now uses raw unaligned features under /content/drive/MyDrive/AmuCS_experiment/features"
for MOD in video km telem; do
  COUNT=$(find "/content/drive/MyDrive/AmuCS_experiment/features/$MOD" -maxdepth 1 -name '*.pt' | wc -l)
  echo "$MOD files: $COUNT"
done
# Out:
# [20/175] skip existing: S011_P3
# [40/175] skip existing: S019_P1
# [60/175] skip existing: S025_P1
# [80/175] skip existing: S030_P1
# [100/175] skip existing: S037_P4
# [120/175] skip existing: S043_P3
# [140/175] skip existing: S048_P4
# [160/175] skip existing: S054_P3
# [175/175] skip existing: S069_P4
# Alignment done.
#   total=175, saved=0, skip_exists=175, skip_no_overlap=0, skip_too_short=0, errors=0
#   report: /content/drive/MyDrive/AmuCS_experiment/features/aligned/alignment_report.json

# %%
# ============================================================
# Cell 12: ???????????
# ============================================================
import glob
print("Using raw unaligned features:")
print("video files:", len(glob.glob("/content/drive/MyDrive/AmuCS_experiment/features/video/*.pt")))
print("km files:", len(glob.glob("/content/drive/MyDrive/AmuCS_experiment/features/km/*.pt")))
print("telem files:", len(glob.glob("/content/drive/MyDrive/AmuCS_experiment/features/telem/*.pt")))
# Out:
# {'input_root': '/content/drive/MyDrive/AmuCS_experiment/features', 'output_root': '/content/drive/MyDrive/AmuCS_experiment/features/aligned', 'modalities': ['video', 'km', 'telem'], 'grid_mode': 'uniform', 'target_hz': 5.0, 'reference_modality': 'video', 'resample': 'nearest', 'time_origin': 'zero', 'offsets': {}, 'max_gap': None, 'total_stems': 175, 'saved_stems': 0, 'skipped_no_overlap': 0, 'skipped_too_short': 0, 'skipped_exists': 175, 'errors': []}
# video files: 180
# km files: 180
# telem files: 175

# %%
# ============================================================
# Cell 13: 构建时序 Arousal 标签
# ============================================================
# 从 RankTrace CSV 构建时间对齐的 arousal 序列标签
# ============================================================
# %%bash
cd /content/ProjectExperiment
python scripts/build_arousal_sequence_labels.py \
  --features_root "/content/drive/MyDrive/AmuCS_experiment/features" \
  --reference_modality video \
  --ranktrace_root "/content/drive/MyDrive/AmuCS/Affective Multimodal Counter-Strike video game dataset (AMuCS) - Public/researchdata/data" \
  --output_path "/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq.json" \
  --time_col VideoTime \
  --value_col arousal \
  --time_unit ms
# Out:
# [50/180] processed
# [100/180] processed
# [150/180] processed
# [180/180] processed
# saved labels: /content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq.json (90)
# saved report: /content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_report.json (90 errors)

# %%
# ============================================================
# Cell 15: 构建多模态数据集划分（按 Session 分组）
# ============================================================
# %%bash
set -e
cd /content/ProjectExperiment

python scripts/build_multimodal_split.py \
  --modality_dirs "/content/drive/MyDrive/AmuCS_experiment/features/video,/content/drive/MyDrive/AmuCS_experiment/features/km,/content/drive/MyDrive/AmuCS_experiment/features/telem" \
  --labels_path "/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq.json" \
  --output_path "/content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json" \
  --val_ratio 0.2 \
  --test_ratio 0.2 \
  --split_by_session \
  --seed 42
# Out:
#   video: 180 files
#   km: 180 files
#   telem: 175 files
# Split saved to: /content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json
#   train: 52 stems
#   val: 17 stems
#   test: 18 stems
#   unique sessions: 51
#   session split -> train: 31, val: 10, test: 10

# %%
# ============================================================
# Cell 17: 序列数据管道诊断
# ============================================================
# %%bash
set -e
cd /content/ProjectExperiment

python scripts/diagnose_seq_pipeline.py \
  --features_root "/content/drive/MyDrive/AmuCS_experiment/features" \
  --labels_seq_path "/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq.json" \
  --split_path "/content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json" \
  --modalities "video,km" \
  --reference_modality "video" \
  --seq_len 600 \
  --train_stride 300 \
  --val_stride 300 \
  --test_stride 300 \
  --include_tail_window \
  --sample_windows 5
# Out:
# === Split Presence ===
# split keys: ['train', 'val', 'test']
# train: 52
# val: 17
# test: 18
#
# === Session Overlap (by stem prefix) ===
# train: sessions=31
# val: sessions=10
# test: sessions=10
# train∩val=0
# train∩test=0
# val∩test=0
#
# === Stem Intersections by Split ===
# train: split=52 labels_inter=52 final_intersection=52
# val: split=17 labels_inter=17 final_intersection=17
# test: split=18 labels_inter=18 final_intersection=18
#
# === Label Scale Stats ===
# all: {'stems_used': 90, 'count_values': 330070, 'min': -539.4676513671875, 'max': 2219.8935546875, 'mean': 39.618021271867704, 'std': 183.66358965995317, 'p1': -237.77542083740235, 'p50': 2.53425931930542, 'p99': 1008.6721929931634, 'valid_mask_ratio_mean': 0.9934488854738218, 'valid_mask_ratio_min': 0.8492985002418965, 'valid_mask_ratio_max': 1.0}
# ...

# %%
# ============================================================
# Cell 18: 标签归一化（Per-Participant Z-score）
# ============================================================
# 依据 AMuCS 论文：
#   "The input and target modalities were normalized
#    per participant (z-score)."
# ============================================================
# %%bash
set -e
cd /content/ProjectExperiment

python scripts/normalize_seq_labels.py \
  --labels_seq_path "/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq.json" \
  --output_path "/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant.json" \
  --stats_output_path "/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant_stats.json" \
  --use_mask
# Out:
# saved normalized labels: /content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant.json (90 stems)
# saved stats: /content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant_stats.json (90 normalized, 0 skipped)

# %%
# ============================================================
# Cell 19: 基线模型评估（训练集均值预测）
# ============================================================
import json
from pathlib import Path
import numpy as np
import torch

features_root = Path("/content/drive/MyDrive/AmuCS_experiment/features")
labels_path = Path("/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant.json")
split_path = Path("/content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json")

modalities = ["video", "km"]
seq_len = 600
strides = {"train": 300, "val": 300, "test": 300}
include_tail = True

labels = json.loads(labels_path.read_text(encoding="utf-8-sig"))
split = json.loads(split_path.read_text(encoding="utf-8-sig"))

def load_feat_len(stem, mod):
    obj = torch.load(features_root/mod/f"{stem}.pt", map_location="cpu", weights_only=False)
    x = obj["features"] if isinstance(obj, dict) else obj
    return int(x.shape[0])

def starts_for(base_len, seq_len, stride, include_tail=True):
    if stride is None or stride <= 0:
        return [(base_len - seq_len)//2 if base_len >= seq_len else 0]
    if base_len <= seq_len:
        return [0]
    max_start = base_len - seq_len
    s = list(range(0, max_start + 1, stride))
    if include_tail and s[-1] != max_start:
        s.append(max_start)
    return s

def collect_split_values(split_name):
    ys = []
    ms = []
    for stem in split.get(split_name, []):
        if stem not in labels:
            continue
        ok = all((features_root/m/f"{stem}.pt").exists() for m in modalities)
        if not ok:
            continue
        y = np.asarray(labels[stem]["values"], dtype=np.float64)
        m = np.asarray(labels[stem].get("mask", [True]*len(y)), dtype=bool)
        base_len = min([len(y)] + [load_feat_len(stem, mm) for mm in modalities])
        y = y[:base_len]
        m = m[:base_len]
        for st in starts_for(base_len, seq_len, strides[split_name], include_tail):
            ed = min(st + seq_len, base_len)
            yw = y[st:ed]
            mw = m[st:ed]
            ys.append(yw)
            ms.append(mw)
    if not ys:
        return np.array([]), np.array([], dtype=bool)
    return np.concatenate(ys), np.concatenate(ms)

def rmse(a, b):
    return float(np.sqrt(np.mean((a-b)**2)))

def ccc(x, y):
    x = x.astype(np.float64); y = y.astype(np.float64)
    mx, my = x.mean(), y.mean()
    vx, vy = x.var(), y.var()
    cov = np.mean((x-mx)*(y-my))
    den = vx + vy + (mx-my)**2
    return float(0.0 if den == 0 else (2*cov/den))

y_train, m_train = collect_split_values("train")
train_mean = y_train[m_train].mean()
print("train_mean:", train_mean)

for sp in ["val", "test"]:
    y, m = collect_split_values(sp)
    yt = y[m]
    pred = np.full_like(yt, train_mean)
    print(f"{sp}: n={len(yt)} mean_baseline_rmse={rmse(pred, yt):.6f} ccc={ccc(pred, yt):.6f}")

# %%
# ============================================================
# Cell 21: 多种子多配置批量训练实验
# ============================================================
# 7 配置 x 3 种子 = 21 次训练
# 标签：per-participant z-score（符合 AMuCS 论文）
# 配置：3个单模态 + 3个双模态 fusion + 1个三模态 fusion
# ============================================================
# %%bash
set -euo pipefail
cd /content/ProjectExperiment

DATA_ROOT="/content/drive/MyDrive/AmuCS_experiment/features"
LABELS="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant.json"
SPLIT="/content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json"
ROOT_RUNS="/content/drive/MyDrive/AmuCS_experiment/runs/cma_perparticipant_z_3seed"

mkdir -p "$ROOT_RUNS"
RESULTS_TSV="$ROOT_RUNS/results.tsv"
echo -e "exp\tseed\trun_dir\tbest_val_rmse\tval_ccc\ttest_rmse\ttest_ccc" > "$RESULTS_TSV"

run_one () {
  EXP_NAME="$1"
  CFG="$2"
  SEED="$3"
  EXP_RUNS="$ROOT_RUNS/$EXP_NAME"
  mkdir -p "$EXP_RUNS"

  TS=$(date +%Y%m%d_%H%M%S)
  LOG="$EXP_RUNS/train_seed${SEED}_${TS}.log"

  echo "===== Start exp=${EXP_NAME} seed=${SEED} =====" | tee -a "$LOG"
  python -u scripts/train.py \
    --config "$CFG" \
    --override \
      data.data_root="$DATA_ROOT" \
      data.labels_seq_path="$LABELS" \
      data.split_path="$SPLIT" \
      data.seq_len=600 \
      data.train_stride=300 \
      data.val_stride=300 \
      data.test_stride=300 \
      data.num_workers=12 \
      train.batch_size=256 \
      train.optimizer.lr=5e-5 \
      train.amp=true \
      train.compile=true \
      train.epochs=40 \
      train.early_stopping.metric=val_rmse \
      train.early_stopping.mode=min \
      train.early_stopping.patience=10 \
      train.seed="$SEED" \
      runs_dir="$EXP_RUNS" \
    model.fusion.name=cma \n      model.fusion.cm_layers=4 \n      model.fusion.sa_layers=2 \n      model.fusion.anchor_modality=video \n      model.fusion.temporal_merge=mean \n    2>&1 | tee -a "$LOG"

  RUN_DIR=$(ls -dt "$EXP_RUNS"/*seed${SEED}/ | head -n1)
  METRICS_JSON="${RUN_DIR}metrics.json"

  python - <<PY
import json, pathlib
m = json.loads(pathlib.Path(r"$METRICS_JSON").read_text(encoding="utf-8"))
best_val_rmse = m.get("best_val_metric", float("nan"))
val_ccc = m.get("val_ccc", float("nan"))
test_rmse = m.get("test_rmse", float("nan"))
test_ccc = m.get("test_ccc", float("nan"))
print(f"exp=$EXP_NAME seed=$SEED run={r'$RUN_DIR'}")
print(f"best_val_rmse={best_val_rmse} val_ccc={val_ccc} test_rmse={test_rmse} test_ccc={test_ccc}")
with open(r"$RESULTS_TSV", "a", encoding="utf-8") as f:
    f.write(f"$EXP_NAME\\t$SEED\\t{r'$RUN_DIR'}\\t{best_val_rmse}\\t{val_ccc}\\t{test_rmse}\\t{test_ccc}\\n")
PY
}

# --- 单模态 ---
# --- 双模态 ---
for SEED in 0 1 2; do
  run_one "dual_video_km_cma" "configs/experiments/video_km_aligned_seq.yaml" "$SEED"
done

for SEED in 0 1 2; do
  run_one "dual_video_telem_cma" "configs/experiments/video_telem_lft_aligned_seq.yaml" "$SEED"
done

# --- 三模态 ---
for SEED in 0 1 2; do
  run_one "triple_video_km_telem_cma" "configs/experiments/video_km_telem_aligned_seq.yaml" "$SEED"
done

python - <<PY
import pandas as pd
from pathlib import Path
p = Path(r"$RESULTS_TSV")
df = pd.read_csv(p, sep="\t")
print("\n=== Per-run Results ===")
print(df[["exp","seed","best_val_rmse","val_ccc","test_rmse","test_ccc"]].to_string(index=False))

g = df.groupby("exp")[["best_val_rmse","val_ccc","test_rmse","test_ccc"]].agg(["mean","std"])
print("\n=== 3-seed Summary (mean/std) ===")
print(g)

out_csv = p.with_name("results_summary.csv")
g.to_csv(out_csv)
print(f"\nSaved:\n- {p}\n- {out_csv}")
PY
# Out:
# ===== Start exp=single_video seed=0 =====
# torch.compile enabled
# Model parameters: 4,271,873 (trainable: 4,271,873)
# Train samples: 605, Val samples: 204
# Run directory: /content/drive/MyDrive/AmuCS_experiment/runs/perparticipant_z_3seed/single_video/2026-03-03_20-30-18__amucs_seq__lft__video__seed0
# Epoch 1/40 | train_ccc: 0.0060 | train_loss: 1.2626 | train_rmse: 1.1237 | val_ccc: 0.0012 | val_rmse: 1.1110
# Epoch 2/40 | train_ccc: 0.0093 | train_loss: 1.1536 | train_rmse: 1.0740 | val_ccc: 0.0152 | val_rmse: 1.0069
# Epoch 3/40 | train_ccc: 0.0266 | train_loss: 0.9825 | train_rmse: 0.9912 | val_ccc: 0.0261 | val_rmse: 1.0051
# Epoch 4/40 | train_ccc: 0.0282 | train_loss: 1.0080 | train_rmse: 1.0040 | val_ccc: 0.0390 | val_rmse: 0.9954
# Epoch 5/40 | train_ccc: 0.0398 | train_loss: 0.9726 | train_rmse: 0.9862 | val_ccc: 0.0510 | val_rmse: 0.9767
# Epoch 6/40 | train_ccc: 0.0457 | train_loss: 0.9507 | train_rmse: 0.9750 | val_ccc: 0.0584 | val_rmse: 0.9841
# ...

# %%
# ============================================================
# Cell 20: H100 训练效率设置
# ============================================================
# 在运行 Cell 21 / 23 / 24 之前执行此 cell
# 所有改动均通过 --override 传入 train.py，无需修改配置文件
# ============================================================
import torch

# TF32：H100 matmul 默认开启，显式声明保险
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True

print(f"Device       : {torch.cuda.get_device_name(0)}")
print(f"VRAM         : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
print(f"PyTorch      : {torch.__version__}")
print(f"TF32 matmul  : {torch.backends.cuda.matmul.allow_tf32}")
print()

# ── H100 推荐训练参数（在下方三个训练 cell 的 --override 中使用）──
# 相比默认值的变化：
#   batch_size   : 32  → 256   （H100 80GB 显存充裕，提升 GPU 利用率）
#   num_workers  : 8   → 16    （Colab H100 实例 CPU 核心更多）
#   train.amp    : -   → true  （BF16 mixed precision，H100 原生支持）
#   train.compile: -   → true  （torch.compile Inductor，约 20-40% 加速）
#   lr           : 2e-5→ 5e-5  （batch size 增大 8x，线性 warmup 缩放）

H100_OVERRIDES = """
      data.num_workers=16 \\
      train.batch_size=256 \\
      train.optimizer.lr=5e-5 \\
      train.amp=true \\
      train.compile=true \\
"""
print("H100 override 参数（复制到下方训练 cell 的 --override 块中）：")
print(H100_OVERRIDES)

# %%
# ============================================================
# Cell 23: 三分类任务——Arousal 低/中/高（7 模态组合 × 3 种子）
# ============================================================
# 步骤：
#   1. 将 arousal_z 连续标签按训练集三分位数离散化为 0/1/2
#   2. 生成 7 个分类实验配置（继承各模态回归配置，深合并覆盖）
#   3. 训练 7 × 3 = 21 个模型
# 评估指标：Macro-F1、Balanced Accuracy（早停依据 val_macro_f1）
# 前置条件：
#   - Cell 11（时间对齐）→ features/aligned/
#   - Cell 15（数据集划分）→ splits/session_tvt.json
#   - Cell 18（标签归一化）→ labels/arousal_seq_z_perparticipant.json
# ============================================================
# %%bash
set -euo pipefail
cd /content/ProjectExperiment

LABELS_Z="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant.json"
SPLIT="/content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json"
LABELS_3CLS="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_3cls_seq.json"
DATA_ROOT="/content/drive/MyDrive/AmuCS_experiment/features"
ROOT_RUNS="/content/drive/MyDrive/AmuCS_experiment/runs/cma_arousal_3cls_3seed"
CLS_CFG_DIR="configs/experiments/cma_cls3"
export LABELS_Z SPLIT LABELS_3CLS CLS_CFG_DIR

mkdir -p "$ROOT_RUNS" "$CLS_CFG_DIR"

# ── 1. 构建三分类标签（仅用训练集三分位数，避免数据泄漏）────────
echo "=== Step 1: Building 3-class labels ==="
python - <<PY
import json, numpy as np, os
from pathlib import Path

labels   = json.loads(Path(os.environ["LABELS_Z"]).read_text(encoding="utf-8-sig"))
split    = json.loads(Path(os.environ["SPLIT"]).read_text(encoding="utf-8-sig"))
out_path = Path(os.environ["LABELS_3CLS"])

if out_path.exists():
    print(f"  Already exists: {out_path}  (skipping)")
else:
    train_vals = [
        v for stem in split.get("train", []) if stem in labels
        for v, m in zip(
            labels[stem]["values"],
            labels[stem].get("mask", [True] * len(labels[stem]["values"])),
        ) if m
    ]
    q33, q67 = np.quantile(train_vals, [1/3, 2/3])
    print(f"  Thresholds (train set): q33={q33:.4f}, q67={q67:.4f}")
    cls_train = [0 if v < q33 else 1 if v < q67 else 2 for v in train_vals]
    for c in range(3):
        print(f"    class {c}: {cls_train.count(c)} ({100*cls_train.count(c)/len(cls_train):.1f}%)")

    out = {}
    for stem, item in labels.items():
        mask = item.get("mask", [True] * len(item["values"]))
        out[stem] = {
            "values": [
                (0 if v < q33 else 1 if v < q67 else 2) if m else 0
                for v, m in zip(item["values"], mask)
            ],
            "mask": mask,
        }
    out_path.parent.mkdir(parents=True, exist_ok=True)
    out_path.write_text(json.dumps(out, ensure_ascii=False), encoding="utf-8")
    print(f"  Saved: {out_path}  ({len(out)} stems)")
PY

# ── 2. 生成分类实验配置（继承回归配置，深合并覆盖 head/loss/metrics）
echo ""
echo "=== Step 2: Generating classification configs ==="
python - <<PY
import yaml, os
from pathlib import Path

LABELS_3CLS = os.environ["LABELS_3CLS"]
CLS_CFG_DIR = Path(os.environ["CLS_CFG_DIR"])
CLS_CFG_DIR.mkdir(parents=True, exist_ok=True)

base_configs = {
    "single_video":          "../video_lft_aligned_seq.yaml",
    "single_km":             "../km_lft_aligned_seq.yaml",
    "single_telem":          "../telem_lft_aligned_seq.yaml",
    "dual_video_km":         "../video_km_aligned_seq.yaml",
    "dual_video_telem":      "../video_telem_lft_aligned_seq.yaml",
    "dual_km_telem":         "../km_telem_lft_aligned_seq.yaml",
    "triple_video_km_telem": "../video_km_telem_aligned_seq.yaml",
}
cls_override = {
    "model": {
        "fusion": {
            "name": "cma",
            "nhead": 8,
            "cm_layers": 4,
            "sa_layers": 2,
            "dim_feedforward": 1024,
            "dropout": 0.1,
            "anchor_modality": "video",
            "max_seq_len": 1000,
            "pos_encoding_type": "sinusoidal",
            "pooling": "mean",
            "temporal_merge": "mean",
        },
        "head": {
            "name": "classification_seq",
            "num_classes": 3,
            "hidden_dim": 128,
            "dropout": 0.1,
        },
    },
    "task_type": "classification",
    "data": {
        "labels_seq_path": LABELS_3CLS,
        "label_dtype": "long",
        "normalize": False,
    },
    "train": {
        "loss": "ce_seq_masked",
        "early_stopping": {"metric": "val_macro_f1", "mode": "max"},
    },
    "eval": {"metrics": ["macro_f1", "balanced_acc"]},
}
for name, base in base_configs.items():
    cfg = {"_base_": base}
    cfg.update(cls_override)
    out = CLS_CFG_DIR / f"{name}.yaml"
    out.write_text(yaml.dump(cfg, allow_unicode=True, default_flow_style=False), encoding="utf-8")
    print(f"  {out}")
PY

# ── 3. 训练 ───────────────────────────────────────────────────
echo ""
echo "=== Step 3: Training 7 configs × 3 seeds ==="

RESULTS_TSV="$ROOT_RUNS/results.tsv"
echo -e "exp\tseed\tbest_val_macro_f1\tval_balanced_acc\ttest_macro_f1\ttest_balanced_acc" > "$RESULTS_TSV"

run_one () {
  EXP_NAME="$1"; SEED="$2"
  EXP_RUNS="$ROOT_RUNS/$EXP_NAME"
  mkdir -p "$EXP_RUNS"

  TS=$(date +%Y%m%d_%H%M%S)
  LOG="$EXP_RUNS/train_seed${SEED}_${TS}.log"

  echo "  ===== ${EXP_NAME} seed=${SEED} =====" | tee -a "$LOG"
  python -u scripts/train.py \
    --config "$CLS_CFG_DIR/${EXP_NAME}.yaml" \
    --override \
      data.data_root="$DATA_ROOT" \
      data.split_path="$SPLIT" \
      data.seq_len=600 \
      data.train_stride=300 \
      data.val_stride=300 \
      data.test_stride=300 \
      data.num_workers=12 \
      train.batch_size=256 \
      train.optimizer.lr=5e-5 \
      train.amp=true \
      train.compile=true \
      train.epochs=40 \
      train.early_stopping.patience=10 \
      train.seed="$SEED" \
      runs_dir="$EXP_RUNS" \
    2>&1 | tee -a "$LOG"

  RUN_DIR=$(ls -dt "$EXP_RUNS"/*seed${SEED}/ | head -n1)
  python - <<PY2
import json, pathlib
m = json.loads(pathlib.Path(r"${RUN_DIR}metrics.json").read_text(encoding="utf-8"))
v_f1  = m.get("best_val_metric",   float("nan"))
v_acc = m.get("val_balanced_acc",  float("nan"))
t_f1  = m.get("test_macro_f1",     float("nan"))
t_acc = m.get("test_balanced_acc", float("nan"))
print(f"  val_macro_f1={v_f1:.4f}  val_bacc={v_acc:.4f}  test_f1={t_f1:.4f}  test_bacc={t_acc:.4f}")
with open(r"$RESULTS_TSV", "a", encoding="utf-8") as f:
    f.write(f"$EXP_NAME\t$SEED\t{v_f1}\t{v_acc}\t{t_f1}\t{t_acc}\n")
PY2
}

EXPS=(dual_video_km dual_video_telem triple_video_km_telem)
for EXP in "${EXPS[@]}"; do
  for SEED in 0 1 2; do run_one "$EXP" "$SEED"; done
done

# ── 汇总 ──────────────────────────────────────────────────────
python - <<PY
import pandas as pd
from pathlib import Path
p = Path(r"$RESULTS_TSV")
df = pd.read_csv(p, sep="\t")
print("\n=== 3-class Arousal — Per-run Results ===")
print(df[["exp","seed","best_val_macro_f1","test_macro_f1","test_balanced_acc"]].to_string(index=False))
g = df.groupby("exp")[["best_val_macro_f1","val_balanced_acc","test_macro_f1","test_balanced_acc"]].agg(["mean","std"])
print("\n=== 3-seed Summary (mean ± std) ===")
print(g)
g.to_csv(p.with_name("results_summary.csv"))
print(f"\nSaved: {p.parent}/results_summary.csv")
PY

# %%
# ============================================================
# Cell 24: 趋势预测——Arousal 下降/平稳/上升（7 模态组合 × 3 种子）
# ============================================================
# 步骤：
#   1. 计算差分 Δarousal_z[t] = arousal_z[t] - arousal_z[t-k]
#      按训练集三分位数离散化为 0/1/2（下降/平稳/上升）
#      前 k 帧（无有效前驱）自动掩码排除，不参与训练和评估
#   2. 生成 7 个趋势分类配置（继承各模态回归配置）
#   3. 训练 7 × 3 = 21 个模型
# 评估指标：Macro-F1、Balanced Accuracy（早停依据 val_macro_f1）
# 超参：TREND_K=5（差分步长，5Hz 下对应 1 秒）
# 前置条件：
#   - Cell 11（时间对齐）→ features/aligned/
#   - Cell 15（数据集划分）→ splits/session_tvt.json
#   - Cell 18（标签归一化）→ labels/arousal_seq_z_perparticipant.json
# ============================================================
# %%bash
set -euo pipefail
cd /content/ProjectExperiment

LABELS_Z="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant.json"
SPLIT="/content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json"
LABELS_TREND="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_3trend_seq.json"
DATA_ROOT="/content/drive/MyDrive/AmuCS_experiment/features"
ROOT_RUNS="/content/drive/MyDrive/AmuCS_experiment/runs/cma_arousal_3trend_3seed"
TREND_CFG_DIR="configs/experiments/cma_trend3"
TREND_K=5   # 差分步长：5Hz × 5步 = 1 秒
export LABELS_Z SPLIT LABELS_TREND TREND_CFG_DIR TREND_K

mkdir -p "$ROOT_RUNS" "$TREND_CFG_DIR"

# ── 1. 构建趋势分类标签 ────────────────────────────────────────
echo "=== Step 1: Building 3-class trend labels (k=$TREND_K steps = $(python3 -c "print($TREND_K/5)") s) ==="
python - <<PY
import json, numpy as np, os
from pathlib import Path

labels   = json.loads(Path(os.environ["LABELS_Z"]).read_text(encoding="utf-8-sig"))
split    = json.loads(Path(os.environ["SPLIT"]).read_text(encoding="utf-8-sig"))
out_path = Path(os.environ["LABELS_TREND"])
K        = int(os.environ["TREND_K"])

if out_path.exists():
    print(f"  Already exists: {out_path}  (skipping)")
else:
    # 仅用训练集的有效差分值计算分位数阈值
    train_deltas = []
    for stem in split.get("train", []):
        if stem not in labels:
            continue
        vals = np.asarray(labels[stem]["values"], dtype=float)
        mask = np.asarray(labels[stem].get("mask", [True] * len(vals)), dtype=bool)
        for t in range(K, len(vals)):
            if mask[t] and mask[t - K]:
                train_deltas.append(float(vals[t] - vals[t - K]))

    q33, q67 = np.quantile(train_deltas, [1/3, 2/3])
    print(f"  Δ Thresholds (train set): q33={q33:.4f}, q67={q67:.4f}")
    cls_train = [0 if d < q33 else 1 if d < q67 else 2 for d in train_deltas]
    labels_name = ["下降(↓)", "平稳(→)", "上升(↑)"]
    for c in range(3):
        print(f"    class {c} {labels_name[c]}: {cls_train.count(c)} ({100*cls_train.count(c)/len(cls_train):.1f}%)")

    # 构建全量趋势标签
    out = {}
    for stem, item in labels.items():
        vals = item["values"]
        orig_mask = item.get("mask", [True] * len(vals))
        trend_vals, trend_mask = [], []
        for t in range(len(vals)):
            valid = t >= K and orig_mask[t] and orig_mask[t - K]
            if valid:
                d = vals[t] - vals[t - K]
                trend_vals.append(0 if d < q33 else 1 if d < q67 else 2)
            else:
                trend_vals.append(0)   # placeholder，mask=False 时被忽略
            trend_mask.append(bool(valid))
        out[stem] = {"values": trend_vals, "mask": trend_mask}

    out_path.parent.mkdir(parents=True, exist_ok=True)
    out_path.write_text(json.dumps(out, ensure_ascii=False), encoding="utf-8")
    print(f"  Saved: {out_path}  ({len(out)} stems)")
PY

# ── 2. 生成趋势分类实验配置 ────────────────────────────────────
echo ""
echo "=== Step 2: Generating trend classification configs ==="
python - <<PY
import yaml, os
from pathlib import Path

LABELS_TREND = os.environ["LABELS_TREND"]
TREND_CFG_DIR = Path(os.environ["TREND_CFG_DIR"])
TREND_CFG_DIR.mkdir(parents=True, exist_ok=True)

base_configs = {
    "single_video":          "../video_lft_aligned_seq.yaml",
    "single_km":             "../km_lft_aligned_seq.yaml",
    "single_telem":          "../telem_lft_aligned_seq.yaml",
    "dual_video_km":         "../video_km_aligned_seq.yaml",
    "dual_video_telem":      "../video_telem_lft_aligned_seq.yaml",
    "dual_km_telem":         "../km_telem_lft_aligned_seq.yaml",
    "triple_video_km_telem": "../video_km_telem_aligned_seq.yaml",
}
trend_override = {
    "model": {
        "fusion": {
            "name": "cma",
            "nhead": 8,
            "cm_layers": 4,
            "sa_layers": 2,
            "dim_feedforward": 1024,
            "dropout": 0.1,
            "anchor_modality": "video",
            "max_seq_len": 1000,
            "pos_encoding_type": "sinusoidal",
            "pooling": "mean",
            "temporal_merge": "mean",
        },
        "head": {
            "name": "classification_seq",
            "num_classes": 3,
            "hidden_dim": 128,
            "dropout": 0.1,
        },
    },
    "task_type": "classification",
    "data": {
        "labels_seq_path": LABELS_TREND,
        "label_dtype": "long",
        "normalize": False,
    },
    "train": {
        "loss": "ce_seq_masked",
        "early_stopping": {"metric": "val_macro_f1", "mode": "max"},
    },
    "eval": {"metrics": ["macro_f1", "balanced_acc"]},
}
for name, base in base_configs.items():
    cfg = {"_base_": base}
    cfg.update(trend_override)
    out = TREND_CFG_DIR / f"{name}.yaml"
    out.write_text(yaml.dump(cfg, allow_unicode=True, default_flow_style=False), encoding="utf-8")
    print(f"  {out}")
PY

# ── 3. 训练 ───────────────────────────────────────────────────
echo ""
echo "=== Step 3: Training 7 configs × 3 seeds ==="

RESULTS_TSV="$ROOT_RUNS/results.tsv"
echo -e "exp\tseed\tbest_val_macro_f1\tval_balanced_acc\ttest_macro_f1\ttest_balanced_acc" > "$RESULTS_TSV"

run_one () {
  EXP_NAME="$1"; SEED="$2"
  EXP_RUNS="$ROOT_RUNS/$EXP_NAME"
  mkdir -p "$EXP_RUNS"

  TS=$(date +%Y%m%d_%H%M%S)
  LOG="$EXP_RUNS/train_seed${SEED}_${TS}.log"

  echo "  ===== ${EXP_NAME} seed=${SEED} =====" | tee -a "$LOG"
  python -u scripts/train.py \
    --config "$TREND_CFG_DIR/${EXP_NAME}.yaml" \
    --override \
      data.data_root="$DATA_ROOT" \
      data.split_path="$SPLIT" \
      data.seq_len=600 \
      data.train_stride=300 \
      data.val_stride=300 \
      data.test_stride=300 \
      data.num_workers=12 \
      train.batch_size=256 \
      train.optimizer.lr=5e-5 \
      train.amp=true \
      train.compile=true \
      train.epochs=40 \
      train.early_stopping.patience=10 \
      train.seed="$SEED" \
      runs_dir="$EXP_RUNS" \
    2>&1 | tee -a "$LOG"

  RUN_DIR=$(ls -dt "$EXP_RUNS"/*seed${SEED}/ | head -n1)
  python - <<PY2
import json, pathlib
m = json.loads(pathlib.Path(r"${RUN_DIR}metrics.json").read_text(encoding="utf-8"))
v_f1  = m.get("best_val_metric",   float("nan"))
v_acc = m.get("val_balanced_acc",  float("nan"))
t_f1  = m.get("test_macro_f1",     float("nan"))
t_acc = m.get("test_balanced_acc", float("nan"))
print(f"  val_macro_f1={v_f1:.4f}  val_bacc={v_acc:.4f}  test_f1={t_f1:.4f}  test_bacc={t_acc:.4f}")
with open(r"$RESULTS_TSV", "a", encoding="utf-8") as f:
    f.write(f"$EXP_NAME\t$SEED\t{v_f1}\t{v_acc}\t{t_f1}\t{t_acc}\n")
PY2
}

EXPS=(dual_video_km dual_video_telem triple_video_km_telem)
for EXP in "${EXPS[@]}"; do
  for SEED in 0 1 2; do run_one "$EXP" "$SEED"; done
done

# ── 汇总 ──────────────────────────────────────────────────────
python - <<PY
import pandas as pd
from pathlib import Path
p = Path(r"$RESULTS_TSV")
df = pd.read_csv(p, sep="\t")
print("\n=== 3-class Trend (↓/→/↑) — Per-run Results ===")
print(df[["exp","seed","best_val_macro_f1","test_macro_f1","test_balanced_acc"]].to_string(index=False))
g = df.groupby("exp")[["best_val_macro_f1","val_balanced_acc","test_macro_f1","test_balanced_acc"]].agg(["mean","std"])
print("\n=== 3-seed Summary (mean ± std) ===")
print(g)
g.to_csv(p.with_name("results_summary.csv"))
print(f"\nSaved: {p.parent}/results_summary.csv")
PY
# Out:
# === Step 1: Building 3-class trend labels (k=5 steps = 1.0 s) ===
#   Already exists: /content/drive/MyDrive/AmuCS_experiment/labels/arousal_3trend_seq.json  (skipping)
#
# === Step 2: Generating trend classification configs ===
#   configs/experiments/trend3/single_video.yaml
#   configs/experiments/trend3/single_km.yaml
#   configs/experiments/trend3/single_telem.yaml
#   configs/experiments/trend3/dual_video_km.yaml
#   configs/experiments/trend3/dual_video_telem.yaml
#   configs/experiments/trend3/dual_km_telem.yaml
#   configs/experiments/trend3/triple_video_km_telem.yaml
#
# === Step 3: Training 7 configs × 3 seeds ===
#   ===== single_video seed=0 =====
# torch.compile enabled
# Model parameters: 4,272,131 (trainable: 4,272,131)
# Train samples: 605, Val samples: 204
# Run directory: /content/drive/MyDrive/AmuCS_experiment/runs/arousal_3trend_3seed/single_video/2026-03-04_09-29-19__amucs_seq__lft__video__seed0
# ...

# %%
# ============================================================
# Cell 25: 构建多任务标签（state + trend）
# ============================================================
# 将两份单任务时序标签合并为一份多任务标签：
#   - arousal_3cls_seq.json   （state：低/中/高）
#   - arousal_3trend_seq.json （trend：下降/平稳/上升）
# 输出：
#   - arousal_state_trend_seq.json
# ============================================================
# %%bash
set -euo pipefail
cd /content/ProjectExperiment

LABELS_STATE="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_3cls_seq.json"
LABELS_TREND="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_3trend_seq.json"
LABELS_MT="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_state_trend_seq.json"

python scripts/merge_multitask_labels.py \
  --state "$LABELS_STATE" \
  --trend "$LABELS_TREND" \
  --output "$LABELS_MT"
# Out:
# Saved multitask labels: /content/drive/MyDrive/AmuCS_experiment/labels/arousal_state_trend_seq.json (stems=90, tasks=state+trend)

# %%
# ============================================================
# Cell 26: 多任务时序分类训练（state + trend）
# ============================================================
# 运行 7 种模态组合 x 3 种子（共 21 次训练）：
#   单模态：single_video / single_km / single_telem
#   双模态：dual_video_km / dual_video_telem / dual_km_telem
#   三模态：triple_video_km_telem
#
# 每次训练会输出任务级指标：
#   val_f1_state, val_f1_trend, val_f1_mean,
#   val_balanced_acc_state, val_balanced_acc_trend 等。
# ============================================================
# %%bash
set -euo pipefail
cd /content/ProjectExperiment

DATA_ROOT="/content/drive/MyDrive/AmuCS_experiment/features"
SPLIT="/content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json"
LABELS_MT="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_state_trend_seq.json"
ROOT_RUNS="/content/drive/MyDrive/AmuCS_experiment/runs/cma_state_trend_multitask_3seed"

CFG_SINGLE_VIDEO="configs/amucs_seq_cma_video_multitask_state_trend.yaml"
CFG_SINGLE_KM="configs/amucs_seq_cma_km_multitask_state_trend.yaml"
CFG_SINGLE_TELEM="configs/amucs_seq_cma_telem_multitask_state_trend.yaml"
CFG_DUAL_VIDEO_KM="configs/amucs_seq_cma_video_km_multitask_state_trend.yaml"
CFG_DUAL_VIDEO_TELEM="configs/amucs_seq_cma_video_telem_multitask_state_trend.yaml"
CFG_DUAL_KM_TELEM="configs/amucs_seq_cma_km_telem_multitask_state_trend.yaml"
CFG_TRIPLE_VIDEO_KM_TELEM="configs/amucs_seq_cma_video_km_telem_multitask_state_trend.yaml"

mkdir -p "$ROOT_RUNS"
RESULTS_TSV="$ROOT_RUNS/results.tsv"
echo -e "exp	seed	val_f1_state	val_f1_trend	val_f1_mean	val_balanced_acc_state	val_balanced_acc_trend	test_f1_state	test_f1_trend	test_f1_mean" > "$RESULTS_TSV"

run_one () {
  EXP_NAME="$1"
  CFG="$2"
  SEED="$3"
  EXP_RUNS="$ROOT_RUNS/$EXP_NAME"
  mkdir -p "$EXP_RUNS"

  TS=$(date +%Y%m%d_%H%M%S)
  LOG="$EXP_RUNS/train_seed${SEED}_${TS}.log"

  echo "===== Start exp=${EXP_NAME} seed=${SEED} =====" | tee -a "$LOG"
  python -u scripts/train.py \
    --config "$CFG" \
    --override \
      data.data_root="$DATA_ROOT" \
      data.labels_seq_path="$LABELS_MT" \
      data.split_path="$SPLIT" \
      data.seq_len=600 \
      data.train_stride=300 \
      data.val_stride=300 \
      data.test_stride=300 \
      data.num_workers=16 \
      train.batch_size=256 \
      train.optimizer.lr=5e-5 \
      train.amp=true \
      train.compile=true \
      train.epochs=40 \
      train.early_stopping.patience=10 \
      train.seed="$SEED" \
      runs_dir="$EXP_RUNS" \
    2>&1 | tee -a "$LOG"

  RUN_DIR=$(ls -dt "$EXP_RUNS"/*seed${SEED}/ | head -n1)
  METRICS_JSON="${RUN_DIR}metrics.json"

  python - <<PY
import json, pathlib
m = json.loads(pathlib.Path(r"$METRICS_JSON").read_text(encoding="utf-8"))
val_f1_state = m.get("val_f1_state", float("nan"))
val_f1_trend = m.get("val_f1_trend", float("nan"))
val_f1_mean = m.get("val_f1_mean", float("nan"))
val_bacc_state = m.get("val_balanced_acc_state", float("nan"))
val_bacc_trend = m.get("val_balanced_acc_trend", float("nan"))
test_f1_state = m.get("test_f1_state", float("nan"))
test_f1_trend = m.get("test_f1_trend", float("nan"))
test_f1_mean = m.get("test_f1_mean", float("nan"))
print(f"val_f1_state={val_f1_state:.4f} val_f1_trend={val_f1_trend:.4f} val_f1_mean={val_f1_mean:.4f}")
print(f"test_f1_state={test_f1_state:.4f} test_f1_trend={test_f1_trend:.4f} test_f1_mean={test_f1_mean:.4f}")
with open(r"$RESULTS_TSV", "a", encoding="utf-8") as f:
    f.write(
        f"$EXP_NAME\t$SEED\t{val_f1_state}\t{val_f1_trend}\t{val_f1_mean}\t"
        f"{val_bacc_state}\t{val_bacc_trend}\t{test_f1_state}\t{test_f1_trend}\t{test_f1_mean}\n"
    )
PY
}

for SEED in 0 1 2; do
  run_one "dual_video_km_multitask_cma" "$CFG_DUAL_VIDEO_KM" "$SEED"
done

for SEED in 0 1 2; do
  run_one "dual_video_telem_multitask_cma" "$CFG_DUAL_VIDEO_TELEM" "$SEED"
done

for SEED in 0 1 2; do
  run_one "triple_video_km_telem_multitask_cma" "$CFG_TRIPLE_VIDEO_KM_TELEM" "$SEED"
done

python - <<PY
import pandas as pd
from pathlib import Path
p = Path(r"$RESULTS_TSV")
df = pd.read_csv(p, sep="\t")
print("\n=== Per-run Results ===")
print(df.to_string(index=False))

summary = df.groupby("exp")[[
    "val_f1_state", "val_f1_trend", "val_f1_mean",
    "val_balanced_acc_state", "val_balanced_acc_trend",
    "test_f1_state", "test_f1_trend", "test_f1_mean",
]].agg(["mean", "std"])
print("\n=== 3-seed Summary (mean/std) ===")
print(summary)

summary_path = p.with_name("results_summary.csv")
summary.to_csv(summary_path)
print(f"\nSaved:\n- {p}\n- {summary_path}")
PY
# Out:
# ===== Start exp=single_video_multitask seed=0 =====
# torch.compile enabled
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Model parameters: 4,338,182 (trainable: 4,338,182)
# Train samples: 605, Val samples: 204
# Run directory: /content/drive/MyDrive/AmuCS_experiment/runs/state_trend_multitask_3seed/single_video_multitask/2026-03-04_10-57-38__amucs_seq_multitask__lft__video__seed0
# ...

# %%
# ============================================================
# Cell 27: 多任务训练（连续Arousal回归 + Trend三分类）
# ============================================================
# 运行 7 种模态组合 x 3 种子（共 21 次训练）：
#   单模态：single_video / single_km / single_telem
#   双模态：dual_video_km / dual_video_telem / dual_km_telem
#   三模态：triple_video_km_telem
#
# 每次训练输出：
#   - arousal回归：val_ccc_arousal, val_rmse_arousal
#   - trend分类：val_macro_f1_trend, val_balanced_acc_trend
#   - 综合指标：val_score_mixed（用于early stopping）
# ============================================================
# %%bash
set -euo pipefail
cd /content/ProjectExperiment

DATA_ROOT="/content/drive/MyDrive/AmuCS_experiment/features"
SPLIT="/content/drive/MyDrive/AmuCS_experiment/splits/session_tvt.json"
LABELS_AROUSAL="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_seq_z_perparticipant.json"
LABELS_TREND="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_3trend_seq.json"
LABELS_MT="/content/drive/MyDrive/AmuCS_experiment/labels/arousal_reg_trend_seq.json"
ROOT_RUNS="/content/drive/MyDrive/AmuCS_experiment/runs/cma_arousal_reg_trend_multitask_3seed"

# Step 0: 合并 arousal（回归）+ trend（分类）标签
python scripts/merge_arousal_reg_trend_labels.py \
  --arousal "$LABELS_AROUSAL" \
  --trend "$LABELS_TREND" \
  --output "$LABELS_MT"

CFG_SINGLE_VIDEO="configs/amucs_seq_cma_video_multitask_arousal_trend.yaml"
CFG_SINGLE_KM="configs/amucs_seq_cma_km_multitask_arousal_trend.yaml"
CFG_SINGLE_TELEM="configs/amucs_seq_cma_telem_multitask_arousal_trend.yaml"
CFG_DUAL_VIDEO_KM="configs/amucs_seq_cma_video_km_multitask_arousal_trend.yaml"
CFG_DUAL_VIDEO_TELEM="configs/amucs_seq_cma_video_telem_multitask_arousal_trend.yaml"
CFG_DUAL_KM_TELEM="configs/amucs_seq_cma_km_telem_multitask_arousal_trend.yaml"
CFG_TRIPLE_VIDEO_KM_TELEM="configs/amucs_seq_cma_video_km_telem_multitask_arousal_trend.yaml"

mkdir -p "$ROOT_RUNS"
RESULTS_TSV="$ROOT_RUNS/results.tsv"
echo -e "exp	seed	best_val_mixed	val_ccc_arousal	val_rmse_arousal	val_macro_f1_trend	val_balanced_acc_trend	test_ccc_arousal	test_rmse_arousal	test_macro_f1_trend	test_balanced_acc_trend	test_score_mixed" > "$RESULTS_TSV"

run_one () {
  EXP_NAME="$1"
  CFG="$2"
  SEED="$3"
  EXP_RUNS="$ROOT_RUNS/$EXP_NAME"
  mkdir -p "$EXP_RUNS"

  TS=$(date +%Y%m%d_%H%M%S)
  LOG="$EXP_RUNS/train_seed${SEED}_${TS}.log"

  echo "===== Start exp=${EXP_NAME} seed=${SEED} =====" | tee -a "$LOG"
  python -u scripts/train.py \
    --config "$CFG" \
    --override \
      data.data_root="$DATA_ROOT" \
      data.labels_seq_path="$LABELS_MT" \
      data.split_path="$SPLIT" \
      data.seq_len=600 \
      data.train_stride=300 \
      data.val_stride=300 \
      data.test_stride=300 \
      data.num_workers=12 \
      train.batch_size=256 \
      train.optimizer.lr=5e-5 \
      train.amp=true \
      train.compile=true \
      train.epochs=40 \
      train.early_stopping.metric=val_score_mixed \
      train.early_stopping.mode=max \
      train.early_stopping.patience=10 \
      train.seed="$SEED" \
      runs_dir="$EXP_RUNS" \
    2>&1 | tee -a "$LOG"

  RUN_DIR=$(ls -dt "$EXP_RUNS"/*seed${SEED}/ | head -n1)
  METRICS_JSON="${RUN_DIR}metrics.json"

  python - <<PY
import json, pathlib
m = json.loads(pathlib.Path(r"$METRICS_JSON").read_text(encoding="utf-8"))
best_val_mixed = m.get("best_val_metric", float("nan"))
val_ccc_arousal = m.get("val_ccc_arousal", float("nan"))
val_rmse_arousal = m.get("val_rmse_arousal", float("nan"))
val_macro_f1_trend = m.get("val_macro_f1_trend", float("nan"))
val_bacc_trend = m.get("val_balanced_acc_trend", float("nan"))
test_ccc_arousal = m.get("test_ccc_arousal", float("nan"))
test_rmse_arousal = m.get("test_rmse_arousal", float("nan"))
test_macro_f1_trend = m.get("test_macro_f1_trend", float("nan"))
test_bacc_trend = m.get("test_balanced_acc_trend", float("nan"))
test_score_mixed = m.get("test_score_mixed", float("nan"))
print(f"best_val_mixed={best_val_mixed:.4f} val_ccc_arousal={val_ccc_arousal:.4f} val_f1_trend={val_macro_f1_trend:.4f}")
print(f"test_ccc_arousal={test_ccc_arousal:.4f} test_f1_trend={test_macro_f1_trend:.4f} test_score_mixed={test_score_mixed:.4f}")
with open(r"$RESULTS_TSV", "a", encoding="utf-8") as f:
    f.write(
        f"$EXP_NAME\t$SEED\t{best_val_mixed}\t{val_ccc_arousal}\t{val_rmse_arousal}\t{val_macro_f1_trend}\t{val_bacc_trend}\t"
        f"{test_ccc_arousal}\t{test_rmse_arousal}\t{test_macro_f1_trend}\t{test_bacc_trend}\t{test_score_mixed}\n"
    )
PY
}

for SEED in 0 1 2; do
  run_one "dual_video_km_multitask_regtrend_cma" "$CFG_DUAL_VIDEO_KM" "$SEED"
done

for SEED in 0 1 2; do
  run_one "dual_video_telem_multitask_regtrend_cma" "$CFG_DUAL_VIDEO_TELEM" "$SEED"
done

for SEED in 0 1 2; do
  run_one "triple_video_km_telem_multitask_regtrend_cma" "$CFG_TRIPLE_VIDEO_KM_TELEM" "$SEED"
done

python - <<PY
import pandas as pd
from pathlib import Path
p = Path(r"$RESULTS_TSV")
df = pd.read_csv(p, sep="\t")
print("\n=== Per-run Results ===")
print(df.to_string(index=False))

summary = df.groupby("exp")[[
    "best_val_mixed",
    "val_ccc_arousal", "val_rmse_arousal",
    "val_macro_f1_trend", "val_balanced_acc_trend",
    "test_ccc_arousal", "test_rmse_arousal",
    "test_macro_f1_trend", "test_balanced_acc_trend",
    "test_score_mixed",
]].agg(["mean", "std"])
print("\n=== 3-seed Summary (mean/std) ===")
print(summary)

summary_path = p.with_name("results_summary.csv")
summary.to_csv(summary_path)
print(f"\nSaved:\n- {p}\n- {summary_path}")
PY
# Out:
# Saved multitask labels: /content/drive/MyDrive/AmuCS_experiment/labels/arousal_reg_trend_seq.json (stems=90, tasks=arousal+trend)
# ===== Start exp=single_video_multitask_regtrend seed=0 =====
# torch.compile enabled
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Model parameters: 4,337,924 (trainable: 4,337,924)
# Train samples: 605, Val samples: 204
# Run directory: /content/drive/MyDrive/AmuCS_experiment/runs/arousal_reg_trend_multitask_3seed/single_video_multitask_regtrend/2026-03-04_12-32-40__amucs_seq_multitask__lft__video__seed0
# ...

# %%
# ============================================================
# Cell 28: 时间滞后扫描分析（Lag Sweep）—— 回归任务全模态组合
# ============================================================
# 作用：对 Cell 21 的 7 种模态回归模型（每个实验取 seed0 最优 checkpoint）
#       在 val 集上扫描 ±2s 时间偏移，诊断 RankTrace 标注相对实际
#       arousal 信号的滞后。
#
# 说明：
#   - 本 cell 面向连续回归任务（CCC/RMSE）
#   - 不用于分类或混合多任务实验
#
# 前置条件：Cell 21（多模态回归训练）已完成
# 结果输出：每个 run_dir 下保存 lag_sweep_val.json
# ============================================================
# %%bash
set -e
cd /content/ProjectExperiment

ROOT_RUNS="/content/drive/MyDrive/AmuCS_experiment/runs/perparticipant_z_3seed"

EXPS=(
  single_video
  single_km
  single_telem
  dual_video_km
  dual_video_telem
  dual_km_telem
  triple_video_km_telem
)

for EXP in "${EXPS[@]}"; do
  EXP_DIR="$ROOT_RUNS/$EXP"
  [ -d "$EXP_DIR" ] || { echo "[SKIP] $EXP - dir not found"; continue; }

  # 取 seed0 做代表性扫描（模态配置从 config.yaml 自动读取）
  RUN_DIR=$(ls -dt "$EXP_DIR"/*seed0/ 2>/dev/null | head -n1)
  [[ -n "$RUN_DIR" && -f "$RUN_DIR/ckpt_best.pt" ]] || {
    echo "[SKIP] $EXP - seed0 checkpoint not found"
    continue
  }

  echo "===== Lag sweep: $EXP ====="
  python scripts/lag_sweep_seq.py \
    --config "$RUN_DIR/config.yaml" \
    --ckpt   "$RUN_DIR/ckpt_best.pt" \
    --split  val \
    --max_lag_sec 2 \
    --step_sec 0.2
  echo ""
done

python - <<'PY'
import json
import pathlib
import pandas as pd

ROOT = pathlib.Path("/content/drive/MyDrive/AmuCS_experiment/runs/perparticipant_z_3seed")
rows = []
for p in sorted(ROOT.glob("*/*/lag_sweep_val.json")):
    if "seed0" not in p.parent.name:
        continue
    exp = p.parent.parent.name
    data = json.loads(p.read_text(encoding="utf-8"))
    bc = data["best_ccc"]
    br = data["best_rmse"]
    rows.append({
        "exp": exp,
        "best_ccc_lag_s": round(bc["lag"] * data["step_sec"], 2),
        "best_ccc": round(bc["ccc"], 4),
        "best_rmse_lag_s": round(br["lag"] * data["step_sec"], 2),
        "best_rmse": round(br["rmse"], 4),
    })

if rows:
    df = pd.DataFrame(rows)
    print("\n=== Lag Sweep Summary (val, seed0) ===")
    print(df.to_string(index=False))
else:
    print("No lag_sweep_val.json found. Please run Cell 21 first.")
PY
# Out:
# ===== Lag sweep: single_video =====
# Traceback (most recent call last):
#   File "/content/ProjectExperiment/scripts/lag_sweep_seq.py", line 180, in <module>
#     main()
#   File "/content/ProjectExperiment/scripts/lag_sweep_seq.py", line 139, in main
#     runner = Runner(cfg, resume=args.ckpt)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ProjectExperiment/src/core/runner.py", line 86, in __init__
#     self._build()
#   File "/content/ProjectExperiment/src/core/runner.py", line 201, in _build
#     self._load_checkpoint(self.resume_ckpt_path)
#   File "/content/ProjectExperiment/src/core/runner.py", line 248, in _load_checkpoint
#     self.model.load_state_dict(model_state)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2635, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for MultimodalModel:
# 	Unexpected key(s) in state_dict: "fusion._modality_emb.embeddings.weight".
# ...
